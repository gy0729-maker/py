# %%
from sklearn.datasets import make_regression

X,y,w = make_regression(n_samples=200, n_features=1, bias=100, noise=10, random_state=1, coef=True)
print(X[:5])
print(y[:5])
print(w)
# Out:
# [[ 0.23249456]
#  [-0.03869551]
#  [ 0.5505375 ]
#  [ 0.50318481]
#  [ 2.18697965]]
# [127.87901739  93.03291422 161.8575084  141.69205026 283.26011945]
# 86.44794300545998

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(X,y)
print(model.intercept_, model.coef_)
# Out:
# 99.79150868986945 [86.96171201]

# %%
#새로운 x값에 대한 y값 예측
model.predict([[-2],[-1],[0],[1],[2]])
# Out:
# array([-74.13191534,  12.82979668,  99.79150869, 186.7532207 ,
#        273.71493272])
