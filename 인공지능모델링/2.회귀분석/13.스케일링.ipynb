# %%
import pandas as pd
df = pd.read_csv('c:/data/boston/house.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  target  target2
# 0  396.90   4.98    24.0        1
# 1  396.90   9.14    21.6        0
# 2  392.83   4.03    34.7        1
# 3  394.63   2.94    33.4        1
# 4  396.90   5.33    36.2        1

# %%
X = df.iloc[:, :-2]
y = df.iloc[:, [-2]]
'+'.join(X.columns)
# Out:
# 'CRIM+ZN+INDUS+CHAS+NOX+RM+AGE+DIS+RAD+TAX+PTRATIO+B+LSTAT'

# %%
import statsmodels.api as sm              # ==>'CRIM+ZN+INDUS+CHAS+NOX+RM+AGE+DIS+RAD+TAX+PTRATIO+B+LSTAT'
model = sm.OLS.from_formula('target ~' + '+'.join(X.columns), data=df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Thu, 15 Jan 2026   Prob (F-statistic):          6.72e-135
# Time:                        12:55:11   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %%
# [2]조건수 cond.No가 너무 커서 강한 다중공선성 또는 다른 수치적 문제가 있을 수 있다.
    #조건수란 가장 큰 값과 가장 작은 값의 비율을 의미함
        #조건수가 커지는 원인 1)변수들의 단위차이=>스케일링  2)다중공선성=>변수제거, 주성분분석 등

# %%
X.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
X.describe().loc['std']  #std : 표준편차
# Out:
# CRIM         8.601545
# ZN          23.322453
# INDUS        6.860353
# CHAS         0.253994
# NOX          0.115878
# RM           0.702617
# AGE         28.148861
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.141062
# Name: std, dtype: float64

# %%
X.boxplot()
# Out:
# <Axes: >

# %%
#Standardization 표준화 평균0, 표준편차1
#데이터를 0을 중심으로 양쪽으로 분포시켜서 평균을 기준으로 얼마나 떨어져 있는지를 나타내는 값
## (측정값 - 평균) / 표준편차

# %%
mean_on_train = X.mean(axis=0)  #평균
std_on_train = X.std(axis=0)  #표준편차
 # 표준화 = (측정값 - 평균 ) / 표준편차
dfx_scaled = (X - mean_on_train)/std_on_train
dfx_scaled.head()
dfx_scaled.describe()
# Out:
#                CRIM            ZN         INDUS          CHAS           NOX  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean  -1.123388e-16  4.037175e-17  3.089316e-16 -3.510587e-17 -2.527622e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.193669e-01 -4.872402e-01 -1.556302e+00 -2.723291e-01 -1.464433e+00
# 25%   -4.105633e-01 -4.872402e-01 -8.668328e-01 -2.723291e-01 -9.121262e-01
# 50%   -3.902803e-01 -4.872402e-01 -2.108898e-01 -2.723291e-01 -1.440749e-01
# 75%    7.389247e-03  4.872402e-02  1.014995e+00 -2.723291e-01  5.980871e-01
# max    9.924110e+00  3.800473e+00  2.420170e+00  3.664771e+00  2.729645e+00
#
#                  RM           AGE           DIS         RAD           TAX  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  506.000000  5.060000e+02
# mean  -9.478584e-17 -1.685082e-16 -1.404235e-16    0.000000  5.616939e-17
# ...

# %%
import matplotlib.pyplot as plt
dfx_scaled.boxplot()
plt.show()

# %%
df_scaled=pd.concat([dfx_scaled, y], axis=1)
model = sm.OLS.from_formula('target ~' + '+'.join(X.columns), data=df_scaled)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Thu, 15 Jan 2026   Prob (F-statistic):          6.72e-135
# Time:                        13:03:10   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.5328      0.211    106.814      0.000      22.118      22.947
# ...

# %%
#스케일링 후 조건수가 9.82로 감소하였다.
