# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import joblib

df = pd.read_csv('c:/data/test/customer_data.csv')

X = df[['age','income','spending_score']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model = KMeans(n_clusters=3, random_state=42)
model.fit(X_scaled)

joblib.dump(model, 'cluster_model.pkl')
joblib.dump(scaler, 'scaler.pkl')

print('클러스터링 모델 저장 완료')
# Out:
# 클러스터링 모델 저장 완료

# %%
df['cluster'] = model.predict(X_scaled)
summary = (df.groupby('cluster')[['age','income','spending_score']].mean().round(1))
print(summary)
# Out:
#           age  income  spending_score
# cluster
# 0        50.0  5900.0            20.0
# 1        29.8  3950.0            67.5
# 2        42.5  5100.0            27.5
