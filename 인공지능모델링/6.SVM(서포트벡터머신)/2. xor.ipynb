# %%
import numpy as np
import mglearn
from matplotlib import pyplot as plt

X_train = np.array([[0,0],[1,0],[0,1],[1,1]])
y_train = np.array([0,1,1,0])
#learn_label = np.array([0,1,1,1])
mglearn.discrete_scatter(X_train[:,0], X_train[:,1], y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x2586e363650>,
#  <matplotlib.lines.Line2D at 0x2586e440a70>]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svm = SVC(kernel = 'rbf')
svm.fit(X_train, y_train)

X_test = np.array([[0,0],[1,0],[0,1],[1,1]])
pred = svm.predict(X_test)

print('정답률=', accuracy_score([0,1,1,0],pred))
# Out:
# 정답률= 1.0

# %%
mglearn.discrete_scatter(X_train[:,0], X_train[:,1], y_train)
mglearn.plots.plot_2d_classification(svm, X_train, cm='spring')
