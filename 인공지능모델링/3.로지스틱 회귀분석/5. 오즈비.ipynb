# %%
A_win = 60
A_lose = 40

B_win = 45
B_lose = 55

odds_A = A_win / A_lose
odds_B = B_win / B_lose

odds_ratio = odds_A / odds_B

print(f'A팀 승산비: {odds_A}')
print(f'B팀 승산비: {odds_B}')
print(f'A팀 vs B팀 승산비: {odds_ratio:.2f}')
# Out:
# A팀 승산비: 1.5
# B팀 승산비: 0.8181818181818182
# A팀 vs B팀 승산비: 1.83

# %%
# A팀은 B팀보다 경기에서 이길 승산(승리:패배 비율)이 약 1.8배 높다
