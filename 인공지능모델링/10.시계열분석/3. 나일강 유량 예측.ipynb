# %%
import pandas as pd
df = pd.read_csv('c:/data/time/nile.csv')
df
# Out:
#        x
# 0   1120
# 1   1160
# 2    963
# 3   1210
# 4   1160
# ..   ...
# 95   746
# 96   919
# 97   718
# 98   714
# 99   740
#
# [100 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
#1차 차분 데이터
diff1 = df['x'].diff(periods=1).iloc[1:]
diff1.plot()
# Out:
# <Axes: >

# %%
from statsmodels.tsa.stattools import adfuller
import numpy as np
#로그 후 차분한 자료를 adfuller 함수로 안정적인 시계열인지 확인
diff1 = np.log(df['x']).diff(periods=1).iloc[1:]
result = adfuller(diff1)
print(result)
# Out:
# (np.float64(-4.748414786012479), np.float64(6.818878743916562e-05), 9, 89, {'1%': np.float64(-3.506057133647011), '5%': np.float64(-2.8946066061911946), '10%': np.float64(-2.5844100201994697)}, np.float64(-64.46023083112888))

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
 #p-value가 0.05보다 작으므로 95% 신뢰수준 하에서 유의함(안정적인 시계열 자료임)
# Out:
# ADF Statistic: -4.748415
# p-value: 0.000068

# %%
from pmdarima.arima import auto_arima
model = auto_arima(df,suppress_warnings=True)
print(model)
#가장 적절한 모형은 arima(1,1,1)
# Out:
#  ARIMA(1,1,1)(0,0,0)[0]

# %%
#학습용, 검증용 구분
n = int(df.shape[0]*.8)
train = df[:n]
test = df[n:]
print(len(df['x']))
print(train['x'].values)
print(test['x'].values)
# Out:
# 100
# [1120 1160  963 1210 1160 1160  813 1230 1370 1140  995  935 1110  994
#  1020  960 1180  799  958 1140 1100 1210 1150 1250 1260 1220 1030 1100
#   774  840  874  694  940  833  701  916  692 1020 1050  969  831  726
#   456  824  702 1120 1100  832  764  821  768  845  864  862  698  845
#   744  796 1040  759  781  865  845  944  984  897  822 1010  771  676
#   649  846  812  742  801 1040  860  874  848  890]
# [ 744  749  838 1050  918  986  797  923  975  815 1020  906  901 1170
#   912  746  919  718  714  740]

# %%
from statsmodels.tsa.arima.model import ARIMA
#order에 auto_arima p,d,q값을 넣어준다
model = ARIMA(train, order=(1,1,1)).fit()
predictions = model.predict(start=1, end=len(test), dynamic=False)
predictions.index = len(train)+(predictions.index-1)
predictions
# Out:
# 80    1108.694660
# 81    1138.469883
# 82    1036.627963
# 83    1142.449874
# 84    1132.672522
# 85    1137.599690
# 86     991.285065
# 87    1139.596737
# 88    1211.331147
# 89    1139.844054
# 90    1080.867168
# 91    1044.754123
# 92    1100.176361
# 93    1055.036289
# 94    1057.275677
# 95    1028.422849
# 96    1106.927009
# 97     965.131282
# 98    1006.482027
# 99    1072.345243
# Name: predicted_mean, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df, label='Real')
plt.plot(predictions, label='Predict')
plt.legend(loc='upper left',fontsize='small')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test, predictions)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 236.3149704735897
