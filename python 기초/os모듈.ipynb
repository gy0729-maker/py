# %%
import os

print('현재 운영체제:', os.name)
print('현재 폴더:', os.getcwd())
print('현재 폴더 내부의 요소:', os.listdir())
os.mkdir('hello')  #폴더생성
os.rmdir('hello')  #폴더삭제
with open('original.txt', 'w') as file:  #파일생성
    file.write('hello')
os.rename('original.txt', 'new.txt')  #파일 이름 변경
os.remove('new.txt')  #파일제거
os.system('dir')
# Out:
# 현재 운영체제: nt
# 현재 폴더: C:\work\python 기초
# 현재 폴더 내부의 요소: ['.idea', '1.변수.ipynb', '10.파일입출력.ipynb', '11.예외처리.ipynb', '12.numpy.ipynb', '13.기초알고리즘.ipynb', '14.pandas-iris.ipynb', '14.pandas-score.ipynb', '14.pandas-wine.ipynb', '14.pandas.ipynb', '15.데이터시각화-house.ipynb', '15.데이터시각화-iris.ipynb', '15.데이터시각화-iris2.ipynb', '15.데이터시각화.ipynb', '15.퀴즈.ipynb', '16.seaborn-penguin.ipynb', '16.seaborn-tip.ipynb', '16.퀴즈.ipynb', '2.조건문.ipynb', '3.반복문.ipynb', '4.집합자료형.ipynb', '5.함수.ipynb', '6.날짜시간.ipynb', '7.random.ipynb', '8.사용자정의함수.ipynb', '9.클래스.ipynb', 'basic.txt', 'even.txt', 'ex01.py', 'gugu2.txt', 'info.txt', 'info_with_bmi.txt', 'numbers.txt', 'numbers_test.txt', 'odd.txt', 'odd2.txt', 'original.txt', 'os모듈.ipynb', 'practice.ipynb', 'practice2.ipynb', 'practice3.ipynb', 'practice4.ipynb', 'practice5.ipynb', 'result.png', 'score.csv', 'words.txt', '금리계산.txt', '히트맵.png']
# 0
