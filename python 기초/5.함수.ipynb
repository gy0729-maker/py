# %%
#dan=input('단을 입력하세요:')
#print(type(dan))
dan=int(input('단을 입력하세요:'))
print(type(dan))

for i in range(1,10):
    print(dan,'x',i,'=',dan*i)
# Out:
# <class 'int'>
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %%
print(10)

a='print(10)'
print(a)
eval(a) #따옴표 제거 후 실행
# Out:
# 10
# print(10)
# 10

# %%
num=1234567890
print( '{0:,}'.format(num))
print( f'{num:,}')
            #:세부사항 ,세자리씩끊어서콤마
num=0.9815
print(f'{num:.0%}')
print(f'{num:.2%}')
            #소수2자리/백분율로 변환
# Out:
# 1,234,567,890
# 1,234,567,890
# 98%
# 98.15%

# %%
for i, num in enumerate([10,20,30,40,50]):
    print(i, num)

for i, name in enumerate(['김철수','박철호','최정호','이철수','홍찬수']):
    print(i,name)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 0 김철수
# 1 박철호
# 2 최정호
# 3 이철수
# 4 홍찬수

# %%
a='사과 배 수박 바나나 포도'
fruits=a.split() #공백기준 문자열 쪼개기
#fruits=['사과','배','수박','바나나','포도']
print(fruits)
print(','.join(fruits))
print('/'.join(fruits))
print('\n'.join(fruits)) #\n 줄바꿈
# Out:
# ['사과', '배', '수박', '바나나', '포도']
# 사과,배,수박,바나나,포도
# 사과/배/수박/바나나/포도
# 사과
# 배
# 수박
# 바나나
# 포도

# %%
a=len('python')
print(a)
b=len([1,2,3])
print(b)
c=len((1, 'a'))
print(c)
# Out:
# 6
# 3
# 2

# %%
a = '\n\t hi '
print(a)
b=a.strip()
print(b)
c=a.lstrip()
print(c)
d=a.rstrip()
print(d)
# Out:
# 	 hi
# hi
# hi
#
# 	 hi

# %%
num=[1,2,3,4,5]
names=['김철수','박철호','최정호','이철수','홍찬수']
points=[100,80,70,60,90]
for (number,name,point) in list(zip(num,names,points)):
    print(number,'이름:',name,', 점수:',point)
# Out:
# 1 이름: 김철수 , 점수: 100
# 2 이름: 박철호 , 점수: 80
# 3 이름: 최정호 , 점수: 70
# 4 이름: 이철수 , 점수: 60
# 5 이름: 홍찬수 , 점수: 90
