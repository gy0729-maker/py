# %%
with open('basic.txt', 'w') as file:
    file.write('with open(문자열: 파일 경로, 문자열: 모드(w/r)) as 파일 객체:\n문장')

# %%
with open('basic.txt', 'r') as file:
    contents =  file.read()
    print(contents)
# Out:
# with open(문자열: 파일 경로, 문자열: 모드(w/r)) as 파일 객체:
# 문장

# %%
import random
hanguls = list('가나다라마바사아자차카타파하')
with open ('info.txt','w') as file:
    for i in range(1000):
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100)
        height = random.randrange(140, 200)
        file.write('{},{},{}\n'.format(name,weight,height))

# %%
#내용 추가하여 새파일로 저장하기

with (open('info.txt','r') as infile,
      open('info_with_bmi.txt', 'w', encoding='utf-8') as outfile
):

    for line in infile:
        (name, weight, height) = line.strip().split(',')
        if (not name) or (not weight) or (not height):
            continue
        bmi = int(weight) / ((int(height)/100)**2)
        result = []
        if 25 <= bmi:
            result = '과체중'
        elif 18.5 <= bmi:
            result = '정상체중'
        else:
            result = '저체중'
        outfile.write(f'{name},{weight},{height},{result}\n')

# %%
numbers = [1,2,3,4,5]

print('::'.join(map(str,numbers)))
# Out:
# 1::2::3::4::5

# %%
#map(함수, 반복가능객체) = “모든 요소에 같은 함수를 적용한다”
print(list(map(lambda x: x**2, numbers)))
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = list(range(1,  10+1))

print('홀수 추출')
print(list(filter(lambda x: x % 2 == 1, numbers)))
print()

print('3이상, 7미만 추출')
print(list(filter(lambda x: 3<=x<7, numbers)))
print()

print('제곱해서 50미만 추출')
print(list(filter(lambda x: x**2<50, numbers)))
# Out:
# 홀수 추출
# [1, 3, 5, 7, 9]
#
# 3이상, 7미만 추출
# [3, 4, 5, 6]
#
# 제곱해서 50미만 추출
# [1, 2, 3, 4, 5, 6, 7]

# %%
try:
    number_input_a = int(input('정수입력>'))
    print('원의반지름:', number_input_a)
    print('원의둘레:', 2*3.14*number_input_a)

except Exception as exception:
    print('type(exception):', type(exception))
    print('exception:', exception)
# Out:
# type(exception): <class 'ValueError'>
# exception: invalid literal for int() with base 10: 'dd'

# %%
import random
numbers = list(range(1, 10+1))
random.shuffle(numbers)
print(numbers)
random.sample(numbers, 3)
# Out:
# [8, 9, 7, 6, 4, 3, 5, 2, 10, 1]
# [9, 8, 4]

# %%
from urllib import request

target = request.urlopen('http://158.179.173.82/')
output = target.read()

print(output)
# Out:
# b'<!DOCTYPE html>\n<html lang="ko">\n<head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <title> AI+X \xec\x8b\xa0\xeb\xa6\xbc \xed\x95\x99\xec\x83\x9d \xec\xbb\xa4\xeb\xae\xa4\xeb\x8b\x88\xed\x8b\xb0 </title>\n    <link rel="stylesheet" href="/static/style.css">\n</head>\n<body>\n    <div class="container">\n        <header>\n            <h1><a href="/">AI+X \xec\x8b\xa0\xeb\xa6\xbc\xeb\xb0\x98 \xed\x95\x99\xec\x83\x9d \xec\xbb\xa4\xeb\xae\xa4\xeb\x8b\x88\xed\x8b\xb0</a></h1>\n            <h4><a href="/">2025-12-23 ~ 2026-05-26</a></h1>\n            <div class="nav-menu">\n                <a href="/board/summary">\xec\x98\xa4\xeb\x8a\x98\xec\x9d\x98 \xec\x88\x98\xec\x97\x85 \xec\x9a\x94\xec\x95\xbd \xea\xb2\x8c\xec\x8b\x9c\xed\x8c\x90 </a>\n                <a href="/board/qna">\xec\xa7\x88\xeb\xac\xb8 / \xeb\x8b\xb5\xeb\xb3\x80 (\xec\x9d\xb5\xeb\xaa\x85) \xea\xb2\x8c\xec\x8b\x9c\xed\x8c\x90 </a>\n                <a href
# ...
