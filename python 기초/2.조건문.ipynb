# %%
color = input('색상을 입력하세요: ')
if color == 'blue':
    print('건너가세요')

if color == 'red':
    print('멈추세요')

else:
    print('끝')
# Out:
# 멈추세요

# %%
num=101
print(num%2)
print(num%2 == 0)
print(num%2 == 1)
# Out:
# 1
# False
# True

# %%
num=int(input('숫자를 입력하세요: '))
if num % 2 == 0:
    print('짝수입니다')

else:
    print('홀수입니다')
# Out:
# 짝수입니다

# %%
color = input('색상을 입력하세요: ')
if color == 'blue' :
    print('건너가세요.')
elif color == 'red' :
    print('멈추세요')
elif color == 'yellow' :
    print('기다리세요')
else:
    print('잘못된 입력입니다.')
# Out:
# 잘못된 입력입니다.
