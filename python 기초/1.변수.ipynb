# %%
a=10
print(a)

a="파이썬"
print(a)
# Out:
# 10
# 파이썬

# %%
a=3
b=4
#3의4승
a**b
# Out:
# 81

# %%
#변수의 삭제 : del
b=2
print(b)
del b
print(b)
# Out:
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 print(b)
#       4 del b
# ----> 5 print(b)
#
# NameError: name 'b' is not defined

# %%
y=3.42134234
print(y)
result='{0:.4f}'.format(y)
# 0 첫번째값 : 세부옵션 float 부동소수점
print(result)

# %%
print(type(10))
print(type(10.5))
print(type("hello"))

# %%
hungry=True
sleepy=False
print(type(hungry)) #bool 논리형
print(not hungry)
print(hungry and sleepy)
print(hungry or sleepy)

# %%
a=1
b=3
if a==1 and b==3: #콜론:블록의 시작/조건식
    print("ok")
#tab으로 들여쓰기

# %%
a='안녕'
b='하세요'
print(a+b)

# %%
name='김철수'
age=20
print('이름 : '+name + ', 나이 : ' +str(age))

# %%
a='파이썬'
print(a*2)
print(3*a)

print('='*50)
print('My Program')
print('='*50)

# %%
a='안녕하세요'
print(a[3])
print(a[-2])
print(a[0:4])
print(a[3:])
print(a[:4])
print(a[:])

# %%
a='신입 개발자'
result=a.replace("신입", "경력")
print(result)

# %%
a='신입 개발자'
result=a.split()
print(result)

a='a:b:c:d'
result=a.split(':')
print(result)

a='가,나,다,라'
result=a.split(',')
print(result)
