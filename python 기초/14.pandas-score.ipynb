# %%
import pandas as pd

df=pd.read_csv('score.csv', encoding='cp949')
print(df)
# Out:
#     이름    점수
# 0   철수  99.0
# 1   영희  80.0
# 2  마이클   NaN
# 3   수민  70.0
# 4  NaN  75.0
# 5   영수  85.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   점수      5 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 228.0+ bytes
# None

# %%
names=df['이름']
print(names)
# Out:
# 0     철수
# 1     영희
# 2    마이클
# 3     수민
# 4    NaN
# 5     영수
# Name: 이름, dtype: object

# %%
high_score=df[df['점수']>=90]
print(high_score)
# Out:
#    이름    점수
# 0  철수  99.0

# %%
# 오름차순 정렬 sorted_df=df.sort_values(by='점수')
sorted_df=df.sort_values(by='점수',ascending=False) #내림차순 정렬
print(sorted_df)
# Out:
#     이름    점수
# 0   철수  99.0
# 5   영수  85.0
# 1   영희  80.0
# 4  NaN  75.0
# 3   수민  70.0
# 2  마이클   NaN

# %%
#NaN=null=결측값
print(df.isnull())
# Out:
#       이름     점수
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4   True  False
# 5  False  False

# %%
# 각 열별 결측지 개수 출력
print(df.isnull().sum())
# Out:
# 이름    1
# 점수    1
# dtype: int64

# %%
df.loc[0,'점수']=90
print(df)
# Out:
#     이름    점수
# 0   철수  90.0
# 1   영희  80.0
# 2  마이클   NaN
# 3   수민  70.0
# 4  NaN  75.0
# 5   영수  85.0

# %%
df.describe()
# Out:
#               점수
# count   5.000000
# mean   80.000000
# std     7.905694
# min    70.000000
# 25%    75.000000
# 50%    80.000000
# 75%    85.000000
# max    90.000000

# %%
print(df.head(3))
# Out:
#     이름    점수
# 0   철수  90.0
# 1   영희  80.0
# 2  마이클   NaN

# %%
print(df.columns)
# Out:
# Index(['이름', '점수'], dtype='object')

# %%
df=df.rename(columns={'점수':'score'})
print(df)
# Out:
#     이름  score
# 0   철수   90.0
# 1   영희   80.0
# 2  마이클    NaN
# 3   수민   70.0
# 4  NaN   75.0
# 5   영수   85.0

# %%
df['결과']=df['score'].apply(
    lambda x : '합격' if x >= 80 else '불합격'
)
print(df)
# Out:
#     이름  score   결과
# 0   철수   90.0   합격
# 1   영희   80.0   합격
# 2  마이클    NaN  불합격
# 3   수민   70.0  불합격
# 4  NaN   75.0  불합격
# 5   영수   85.0   합격

# %%
df['결과']=df

# %%
print(df['결과'].value_counts())
# Out:
# 결과
# 합격     3
# 불합격    3
# Name: count, dtype: int64

# %%
print(df.dtypes)
# Out:
# 이름        object
# score    float64
# 결과        object
# dtype: object
