# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %%
df=pd.read_csv('c:/work/수행평가/fastfood_health.csv')
df.head()
# Out:
#    Age  Gender  Fast_Food_Meals_Per_Week  Average_Daily_Calories   BMI  \
# 0   56    Male                         1                    3153  28.4
# 1   46    Male                        12                    1748  22.8
# 2   32  Female                         8                    3020  21.5
# 3   25  Female                         6                    2621  26.8
# 4   38  Female                        14                    2260  18.1
#
#    Physical_Activity_Hours_Per_Week  Sleep_Hours_Per_Day  Energy_Level_Score  \
# 0                               4.5                  7.8                   9
# 1                               9.6                  6.7                   2
# 2                               4.0                  7.4                   2
# 3                               8.4                  6.1                   6
# 4                               1.9                  7.7                   7
#
#   Digestive_Issues  Doctor_Visits_Per_Year  Overall_Health_Score
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Fast_Food_Meals_Per_Week', 'Average_Daily_Calories',
#        'BMI', 'Physical_Activity_Hours_Per_Week', 'Sleep_Hours_Per_Day',
#        'Energy_Level_Score', 'Digestive_Issues', 'Doctor_Visits_Per_Year',
#        'Overall_Health_Score'],
#       dtype='object')

# %%
print(df.describe())
# Out:
#               Age  Fast_Food_Meals_Per_Week  Average_Daily_Calories  \
# count  800.000000                800.000000              800.000000
# mean    38.802500                  6.818750             2554.728750
# std     12.055919                  4.329183              551.078974
# min     18.000000                  0.000000             1600.000000
# 25%     29.000000                  3.000000             2084.750000
# 50%     40.000000                  7.000000             2540.500000
# 75%     49.000000                 11.000000             3049.000000
# max     59.000000                 14.000000             3499.000000
#
#              BMI  Physical_Activity_Hours_Per_Week  Sleep_Hours_Per_Day  \
# count  800.00000                        800.000000           800.000000
# mean    26.43900                          4.938000             6.472875
# std      4.94144                          2.860272             1.429232
# ...

# %%
gender_count = df['Gender'].value_counts().sort_values(ascending=False)
print(gender_count)
# Out:
# Gender
# Male      385
# Female    381
# Other      34
# Name: count, dtype: int64

# %%
plt.pie(
    gender_count,
    labels=['Male','Female','Other'],
    autopct='%.1f%%',
    startangle=90
)
plt.show()

# %%
print(df['Age'].min())
print(df['Age'].max())
print(df['Age'].mean())
# Out:
# 18
# 59
# 38.8025

# %%
df.info()
sns.set_theme='whitegrid'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               800 non-null    int64
#  1   Gender                            800 non-null    object
#  2   Fast_Food_Meals_Per_Week          800 non-null    int64
#  3   Average_Daily_Calories            800 non-null    int64
#  4   BMI                               800 non-null    float64
#  5   Physical_Activity_Hours_Per_Week  800 non-null    float64
#  6   Sleep_Hours_Per_Day               800 non-null    float64
#  7   Energy_Level_Score                800 non-null    int64
#  8   Digestive_Issues                  800 non-null    object
#  9   Doctor_Visits_Per_Year            800 non-null    int64
#  10  Overall_Health_Score              800 non-null    int64
# dtypes: float64(3), int64(6), object(2)
# ...

# %%
sns.barplot(
    x='Gender',
    y='Fast_Food_Meals_Per_Week',
    data=df
)
plt.show()

# %%
sns.barplot(
    y='Gender',
    x='Fast_Food_Meals_Per_Week',
    data=df
)
plt.show()

# %%
sns.histplot(
    df['BMI'],
    bins=20
)
plt.show()

# %%
sns.boxplot(x='Gender',y='Sleep_Hours_Per_Day',data=df)
plt.show()

# %%
plt.figure()
sns.scatterplot(
    x='Fast_Food_Meals_Per_Week',
    y='Overall_Health_Score',
    data=df,
)
plt.show()

# %%
corr=df[['Age','Fast_Food_Meals_Per_Week','Average_Daily_Calories','BMI','Physical_Activity_Hours_Per_Week','Sleep_Hours_Per_Day','Energy_Level_Score','Doctor_Visits_Per_Year','Overall_Health_Score']].corr()
print(corr)
# Out:
#                                        Age  Fast_Food_Meals_Per_Week  \
# Age                               1.000000                 -0.002797
# Fast_Food_Meals_Per_Week         -0.002797                  1.000000
# Average_Daily_Calories            0.046907                 -0.045497
# BMI                              -0.009167                 -0.036539
# Physical_Activity_Hours_Per_Week -0.074306                 -0.059734
# Sleep_Hours_Per_Day              -0.058478                  0.026714
# Energy_Level_Score               -0.043659                 -0.006475
# Doctor_Visits_Per_Year            0.040079                  0.007510
# Overall_Health_Score             -0.007558                  0.037271
#
#                                   Average_Daily_Calories       BMI  \
# Age                                             0.046907 -0.009167
# Fast_Food_Meals_Per_Week                       -0.045497 -0.036539
# Average_Daily_Calories                          1.000000  0.048395
# ...

# %%
sns.heatmap(corr,annot=True)
plt.savefig('fastfood_health_heatmap.png')

# %%
sns.regplot(x='Fast_Food_Meals_Per_Week',y='Overall_Health_Score',data=df)
plt.show()

# %%
sns.pairplot(df, hue='Gender')
plt.show()
