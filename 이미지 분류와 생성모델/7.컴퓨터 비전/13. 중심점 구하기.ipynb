# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('c:/images/convex.jpg')
src = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(src)
plt.axis('off')
plt.show()

# %%
dst = src.copy()
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
                 #이미지 이진화 -> 150 이상이면 1, 미만이면 0으로 분류
ret, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)
#외곽선 검출
contours, hierarchy = cv2.findContours(binary, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)
for i in contours:
    #중심좌표 구하기
    #cv2.moments(배열, 이진화 이미지)
    M = cv2.moments(i)
    cX = int(M['m10'] / M['m00'])
    cY = int(M['m01'] / M['m00'])

    cv2.circle(dst, (cX, cY), 3, (255,255,0), -1)
    #외곽선 그리기
    cv2.drawContours(dst, [i], 0, (255,0,0), 2)

# %%
plt.imshow(dst)
plt.title('image1')
plt.axis('off')
plt.show()
