# %%
import cv2

img = cv2.imread('c:/images/penguin.png')
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
height, width, channel = img.shape
print(height, width, channel)
# Out:
# 128 107 3

# %%
degrees = [45, 90, 180, 270]
images = []
for degree in degrees:
        #get rotation matrix2d (회전중심좌표, 각도, 축소/확대비율) ->반시계방향
    matrix = cv2.getRotationMatrix2D((width / 2, height / 2), degree, 1)
    dst = cv2.warpAffine(img, matrix, (width, height))
    images.append(dst)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.subplot(1,5,1)
plt.imshow(image_rgb)
plt.title('original')
plt.axis('off')
for idx, image in enumerate(images):
    plt.subplot(1,5,idx+2)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(f'{degrees[idx]}-degree')
    plt.axis('off')
    idx += 1
plt.show()
