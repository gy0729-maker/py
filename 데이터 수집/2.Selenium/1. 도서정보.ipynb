# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

ChromeDriverManager().install()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
import time
from selenium.webdriver.common.keys import Keys

driver.get('https://www.kyobobook.co.kr/')
time.sleep(3)

keyword = '클로드'
driver.find_element('xpath', '//*[@id="searchKeyword"]').send_keys(keyword)
driver.find_element('xpath', '//*[@id="searchKeyword"]').send_keys(Keys.RETURN)

# %%
#도서명
titles = []
for i in range(1,21):
    title = driver.find_element('xpath', f'//*[@id="shopData_list"]/ul/li[{i}]/div[1]/div[2]/div[2]/div[1]/div/a').text
    titles.append(title)

# %%
titles
# Out:
# ['[국내도서] 혼자 공부하는 바이브 코딩 with 클로드 코드',
#  '[국내도서] 챗GPT·퍼플렉시티·클로드·코파일럿·제미나이 다 잘함',
#  '[국내도서] 요즘 바이브 코딩 클로드 코드 완벽 가이드',
#  '[국내도서] AI 자율학습 클로드 코드·코덱스 CLI·제미나이 CLI 완전 활용법',
#  '[eBook] 혼자 공부하는 바이브 코딩 with 클로드 코드',
#  '[국내도서] 한 걸음 앞선 개발자가 지금 꼭 알아야 할 클로드 코드',
#  '[eBook] 요즘 바이브 코딩 클로드 코드 완벽 가이드',
#  '[eBook] 한 걸음 앞선 개발자가 지금 꼭 알아야 할 클로드 코드',
#  '[eBook] 챗GPT·퍼플렉시티·클로드·코파일럿·제미나이 다 잘함',
#  '[eBook] AI 자율학습 클로드 코드·코덱스 CLI·제미나이 CLI 완전 활용법',
#  '[국내도서] 클로드 모네',
#  '[국내도서] 보고서 기획서 고민 없이 시작해서 30분 만에 끝내주는 프롬프트 책',
#  '[국내도서] 바이브 코딩 (커서 AI와 클로드 코드로 누구나!)',
#  '[국내도서] 향수가 된 식물들',
#  '[eBook] 클로드 나의 첫 목회 비서',
#  '[국내도서] 이게 되네? 클로드 MCP 미친 활용법 27제',
#  '[국내도서] 생성형 AI 활용 백과사전',
#  '[국내도서] 하나님을 경험하는 삶(교재)',
#  '[국내도서] 예약판매 모네의 숲에서 월든을 읽고 필사하다',
#  '[국내도서] LLM 프롬프트 활용 교과서']
