# %%
import requests
from bs4 import BeautifulSoup

url = 'https://finance.naver.com/item/sise.naver?code=005930'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

table = soup.find('table', {'class': 'type2'})
rows = table.find_all('tr')

for row in rows[:10]:
    cols = row.find_all(['th', 'td'])
    if cols:
        print([col.get_text(strip=True) for col in cols])
# Out:
# ['현재가', '166,500', '매도호가', '166,300']
# ['전일대비', '상승700', '매수호가', '166,200']
# ['등락률(%)', '+0.42%', '전일가', '165,800']
# ['거래량', '11,004,378', '시가', '164,000']
# ['거래대금(백만)', '1,811,808', '고가', '166,600']
# ['액면가', '100원', '저가', '162,000']
# ['']
# ['상한가', '215,500', '전일상한', '216,000']
# ['하한가', '116,100', '전일하한', '116,500']
# ['PER', '34.57', 'EPS', '4,816']
