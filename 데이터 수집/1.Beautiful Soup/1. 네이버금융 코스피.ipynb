# %%
import urllib.request as req
from bs4 import BeautifulSoup

url = 'http://finance.naver.com'
res = req.urlopen(url)
bs = BeautifulSoup(res, 'html.parser')
val = bs.select_one('#content > div.article > div.section2 > div.section_stock_market > div.section_stock > div.kospi_area.group_quot.quot_opn > div.heading_area > a > span > span.num').text
print('코스피지수=', val)

val = bs.select_one('#content > div.article > div.section2 > div.section_stock_market > div.section_stock > div.kosdaq_area.group_quot > div.heading_area > a > span > span.num').text
print('코스닥지수=', val)
# Out:
# 코스피지수= 5,335.81
# 코스닥지수= 1,121.85
