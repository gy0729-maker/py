# %%
import pandas as pd
from sqlalchemy import create_engine

csv_path= 'c:/data/text/news.csv'
df = pd.read_csv(csv_path, encoding='ms949')
print(df.head())
# Out:
#   keyword                                              title  link
# 0     반도체  HBM 다음엔 HBF 시대 온다, 삼전·하닉 아직 안 늦은 까닭 [반도체 대전망 ①...   NaN
# 1     반도체  반도체 호황에 가려진 삼성전자 완제품 사업의 위기… TV·가전 수익성 확보 과제 -...   NaN
# 2     반도체            삼성·하이닉스 10조 던진 외인…K반도체 앞날은 - v.daum.net   NaN
# 3     반도체       “美, 빅테크에 반도체 관세 면제 계획…TSMC 대미투자와 연계” - 헤럴드경제   NaN
# 4     반도체                  韓, 네덜란드·이탈리아와 반도체·AI 공조 확대 - 전자신문   NaN

# %%
user = 'user'
password = '1234'
host = 'localhost'
port = 3306
database = 'mydb'
engine = create_engine('mysql+mysqldb://user:1234@localhost:3306/mydb?charset=utf8')

df.to_sql(name='news', con=engine, if_exists='replace', index=False)

print('MySQL export 완료')
# Out:
# MySQL export 완료
