# %%
import requests
from bs4 import BeautifulSoup
from bs4 import XMLParsedAsHTMLWarning
import warnings

warnings.filterwarnings('ignore', category=XMLParsedAsHTMLWarning)

keywords = ['반도체', 'AI', '환율']

for kw in keywords:
    url = f'https://news.google.com/rss/search?q={kw}&hl=ko&gl=KR&ceid=KR:ko'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    print(f'\n[{kw}]')
    for item in soup.find_all('item')[:5]:
        print('-', item.title.text)
# Out:
# [반도체]
# - 반도체 호황에 가려진 삼성전자 완제품 사업의 위기… TV·가전 수익성 확보 과제 - 조선비즈 - Chosunbiz
# - HBM 다음엔 HBF 시대 온다, 삼전·하닉 아직 안 늦은 까닭 [반도체 대전망 ①] - 중앙일보
# - 경북도·구미시, '반도체 팹' 유치 제안..재계 300조 지방 투자 계획 대응 - 머니투데이
# - 세미콘 코리아 2026 개막…반도체 공급망 협력·연계 모색 - 뉴시스
# - 문신학 산업차관 "반도체 산업 든든한 버팀목 될 것"…'세미콘 코리아 2026' 개막 - v.daum.net
#
# [AI]
# - AI끼리 대화한다더니…인간이 연출한 쇼였다 - 동아일보
# - 인텔리빅스-빌드엠파트너스, ‘행동하는 AI’ 기반 차세대 빌딩안전 플랫폼 구축 맞손 - v.daum.net
# - AI끼리 논문 만들고 서로 인용... 가짜 학술 사이트까지 생겼다 - 조선일보
# - [유미's 픽] 李 'AI 고속도로'가 바꾼 판…정부 GPU 지원, 스타트업 실험에 불 붙였다 - 지디넷코리아
# - 방미통위, AI·디지털 기반 방송콘텐츠에 72억 지원 - 연합뉴스
#
# [환율]
# - 원/달러 환율 사흘째 하락세…장 초반 1,458.1원 - 연합뉴스
# - "다카이치부터 앤트로픽까지" 환율 급등락 [3분 브리프] - 아시아경제
# - 구윤철 부총리 “수입 물가 낮추도록 환율 안정 위해 노력할 것” - 조선비즈 - Chosunbiz
# - 구윤철 "환율 안정으로 수입 물가 안정 노력…집값 안정은 최고 정책 목표" - v.daum.net
# - 金총리 "환율, 펀더멘털·외환보유 문제 아냐…현재는 수급반영" - 연합뉴스
